# %% [markdown]
# Вы получили основные навыки обработки данных, теперь пора испытать их на практике. Сейчас вам предстоит заняться задачей классификации.
#
# Представлен датасет центра приюта животных, и вашей задачей будет обучить модель таким образом, чтобы  по определенным признакам была возможность максимально уверенно предсказать метки 'Adoption' и 'Transfer' (столбец “outcome_type”).
#
# Здесь вы вольны делать что угодно. Я хочу видеть от вас:
# 1. Проверка наличия/обработка пропусков
# 2. Проверьте взаимосвязи между признаками
# 3. Попробуйте создать свои признаки
# 4. Удалите лишние
# 5. Обратите внимание на текстовые столбцы. Подумайте, что можно извлечь полезного оттуда
# 6. Использование профайлера вам поможет.
# 7. Не забывайте, что у вас есть PCA (Метод главных компонент). Он может пригодиться.
#
# Вспомните о всем, что я говорил на предыдущих занятиях. Не все будет пригодится, но в жизни вам никто не будет говорить, что использовать :)
#
# Хорошим классификатором для этой задачи будет "Случайный лес" (https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)
#
# Понимать суть работы "леса" не обязательно на данном этапе, но качество предсказаний будет выше, чем с линейным классификатором. (если желаете, вот гайд https://adataanalyst.com/scikit-learn/linear-classification-method/)
#
# Желаю успеха :)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
from scipy import stats

# %%
data = pd.read_csv('data/aac_shelter_outcomes.csv')

# %%
data
# Out:
#       age_upon_outcome animal_id animal_type  \
# 0              2 weeks   A684346         Cat
# 1               1 year   A666430         Dog
# 2               1 year   A675708         Dog
# 3              9 years   A680386         Dog
# 4             5 months   A683115       Other
# ...                ...       ...         ...
# 78251          1 month   A764894         Dog
# 78252          3 years   A764468         Dog
# 78253              NaN   A766098       Other
# 78254         2 months   A765858         Dog
# 78255         2 months   A765857         Dog
#
#                                      breed         color        date_of_birth  \
# 0                   Domestic Shorthair Mix  Orange Tabby  2014-07-07T00:00:00
# 1                               Beagle Mix   White/Brown  2012-11-06T00:00:00
# 2                                 Pit Bull    Blue/White  2013-03-31T00:00:00
# 3                  Miniature Schnauzer Mix         White  2005-06-02T00:00:00
# 4                                  Bat Mix         Brown  2014-01-07T00:00:00
# ...                                    ...           ...                  ...
# 78251  Golden Retriever/Labrador Retriever   Brown/White  2017-12-04T00:00:00
# 78252                          Mastiff Mix    Blue/White  2014-12-30T00:00:00
# 78253                              Bat Mix         Brown  2017-02-01T00:00:00
# 78254                   Standard Schnauzer           Red  2017-11-13T00:00:00
# 78255               Labrador Retriever Mix   White/Brown  2017-11-13T00:00:00
#
#                   datetime            monthyear     name outcome_subtype  \
# 0      2014-07-22T16:04:00  2014-07-22T16:04:00      NaN         Partner
# 1      2013-11-07T11:47:00  2013-11-07T11:47:00     Lucy         Partner
# 2      2014-06-03T14:20:00  2014-06-03T14:20:00  *Johnny             NaN
# 3      2014-06-15T15:50:00  2014-06-15T15:50:00   Monday         Partner
# 4      2014-07-07T14:04:00  2014-07-07T14:04:00      NaN     Rabies Risk
# ...                    ...                  ...      ...             ...
# 78251  2018-02-01T18:26:00  2018-02-01T18:26:00      NaN          Foster
# 78252  2018-02-01T18:06:00  2018-02-01T18:06:00      Max             NaN
# 78253  2018-02-01T18:08:00  2018-02-01T18:08:00      NaN     Rabies Risk
# 78254  2018-02-01T18:32:00  2018-02-01T18:32:00      NaN             NaN
# 78255  2018-02-01T18:44:00  2018-02-01T18:44:00      NaN             NaN
#
#       outcome_type sex_upon_outcome
# 0         Transfer      Intact Male
# 1         Transfer    Spayed Female
# 2         Adoption    Neutered Male
# 3         Transfer    Neutered Male
# 4       Euthanasia          Unknown
# ...            ...              ...
# 78251     Adoption    Spayed Female
# 78252     Adoption    Neutered Male
# 78253   Euthanasia          Unknown
# 78254     Adoption    Spayed Female
# 78255     Adoption    Neutered Male
#
# [78256 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78256 entries, 0 to 78255
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age_upon_outcome  78248 non-null  object
#  1   animal_id         78256 non-null  object
#  2   animal_type       78256 non-null  object
#  3   breed             78256 non-null  object
#  4   color             78256 non-null  object
#  5   date_of_birth     78256 non-null  object
#  6   datetime          78256 non-null  object
#  7   monthyear         78256 non-null  object
#  8   name              54370 non-null  object
#  9   outcome_subtype   35963 non-null  object
#  10  outcome_type      78244 non-null  object
#  11  sex_upon_outcome  78254 non-null  object
# dtypes: object(12)
# memory usage: 7.2+ MB

# %%
data['outcome_type'].value_counts()
# Out:
# Adoption           33112
# Transfer           23499
# Return to Owner    14354
# Euthanasia          6080
# Died                 680
# Disposal             307
# Rto-Adopt            150
# Missing               46
# Relocate              16
# Name: outcome_type, dtype: int64

# %% [markdown]
# # План действий
#
# 1 В датасете по столбцу outcome_type оставляем строки со значениями Adoption и Transfer
#
# 2 обработаем столбцы с пропусками:
#
# age_upon_outcome - пропуски можно удалить, так как их немного и это не повлияет на модель
#
# name - удалять нельзя, пропусков много, но можно удалить столбец, так как имя ни на что не влияет
#
# outcome_subtype - удалять нельзя, много пропусков
#
# outcome_type - пропуски можно удалить, так как их немного и это не повлияет на модель
#
# sex_upon_outcome - пропуски можно удалить, так как их немного и это не повлияет на модель
#
# 3 Столбец animal_id удалим, он не вляет на модель, просто присвоенный номер
#
# 4 Столбец age_upon_outcome преобразуем в численные значения
#
# 5 Столбец outcome_subtype преобразуем с помощью OneHotEncoding
#
# 6 Столбцы date_of_birth, datetime, monthyear взаимосвязаны с age_upon_outcome, причем datetime и monthyear дублируются из за аномалии, удаляем

# %%
data = data[(data['outcome_type']=='Adoption') | (data['outcome_type']=='Transfer')]
data
# Out:
#       age_upon_outcome animal_id animal_type  \
# 0              2 weeks   A684346         Cat
# 1               1 year   A666430         Dog
# 2               1 year   A675708         Dog
# 3              9 years   A680386         Dog
# 5             4 months   A664462         Dog
# ...                ...       ...         ...
# 78250          1 month   A764895         Dog
# 78251          1 month   A764894         Dog
# 78252          3 years   A764468         Dog
# 78254         2 months   A765858         Dog
# 78255         2 months   A765857         Dog
#
#                                      breed         color        date_of_birth  \
# 0                   Domestic Shorthair Mix  Orange Tabby  2014-07-07T00:00:00
# 1                               Beagle Mix   White/Brown  2012-11-06T00:00:00
# 2                                 Pit Bull    Blue/White  2013-03-31T00:00:00
# 3                  Miniature Schnauzer Mix         White  2005-06-02T00:00:00
# 5                           Leonberger Mix   Brown/White  2013-06-03T00:00:00
# ...                                    ...           ...                  ...
# 78250  Golden Retriever/Labrador Retriever   Brown/White  2017-12-04T00:00:00
# 78251  Golden Retriever/Labrador Retriever   Brown/White  2017-12-04T00:00:00
# 78252                          Mastiff Mix    Blue/White  2014-12-30T00:00:00
# 78254                   Standard Schnauzer           Red  2017-11-13T00:00:00
# 78255               Labrador Retriever Mix   White/Brown  2017-11-13T00:00:00
#
#                   datetime            monthyear     name outcome_subtype  \
# 0      2014-07-22T16:04:00  2014-07-22T16:04:00      NaN         Partner
# 1      2013-11-07T11:47:00  2013-11-07T11:47:00     Lucy         Partner
# 2      2014-06-03T14:20:00  2014-06-03T14:20:00  *Johnny             NaN
# 3      2014-06-15T15:50:00  2014-06-15T15:50:00   Monday         Partner
# 5      2013-10-07T13:06:00  2013-10-07T13:06:00   *Edgar         Partner
# ...                    ...                  ...      ...             ...
# 78250  2018-02-01T18:40:00  2018-02-01T18:40:00      NaN          Foster
# 78251  2018-02-01T18:26:00  2018-02-01T18:26:00      NaN          Foster
# 78252  2018-02-01T18:06:00  2018-02-01T18:06:00      Max             NaN
# 78254  2018-02-01T18:32:00  2018-02-01T18:32:00      NaN             NaN
# 78255  2018-02-01T18:44:00  2018-02-01T18:44:00      NaN             NaN
#
#       outcome_type sex_upon_outcome
# 0         Transfer      Intact Male
# 1         Transfer    Spayed Female
# 2         Adoption    Neutered Male
# 3         Transfer    Neutered Male
# 5         Transfer      Intact Male
# ...            ...              ...
# 78250     Adoption    Neutered Male
# 78251     Adoption    Spayed Female
# 78252     Adoption    Neutered Male
# 78254     Adoption    Spayed Female
# 78255     Adoption    Neutered Male
#
# [56611 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56611 entries, 0 to 78255
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age_upon_outcome  56609 non-null  object
#  1   animal_id         56611 non-null  object
#  2   animal_type       56611 non-null  object
#  3   breed             56611 non-null  object
#  4   color             56611 non-null  object
#  5   date_of_birth     56611 non-null  object
#  6   datetime          56611 non-null  object
#  7   monthyear         56611 non-null  object
#  8   name              38660 non-null  object
#  9   outcome_subtype   29425 non-null  object
#  10  outcome_type      56611 non-null  object
#  11  sex_upon_outcome  56611 non-null  object
# dtypes: object(12)
# memory usage: 5.6+ MB

# %%
# удаляем пропуски в столбце age_upon_outcome
data = data.dropna(subset=['age_upon_outcome'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56609 entries, 0 to 78255
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age_upon_outcome  56609 non-null  object
#  1   animal_id         56609 non-null  object
#  2   animal_type       56609 non-null  object
#  3   breed             56609 non-null  object
#  4   color             56609 non-null  object
#  5   date_of_birth     56609 non-null  object
#  6   datetime          56609 non-null  object
#  7   monthyear         56609 non-null  object
#  8   name              38660 non-null  object
#  9   outcome_subtype   29423 non-null  object
#  10  outcome_type      56609 non-null  object
#  11  sex_upon_outcome  56609 non-null  object
# dtypes: object(12)
# memory usage: 5.6+ MB

# %%
# в результате пропуски исчезли вместе с удаленными строками

# %%
# удалим столбец animal_id
data = data.drop(['animal_id'], axis=1)

# %%
data.shape
# Out:
# (56609, 11)

# %%
# data

# %%
# видно, что datetime - date_of_birth = age_upon_outcome, с округлением
# сначала преобразуем datetime и date_of_birth, отбросим время, так как оно не всегда указано корректно

# %%
data['date_of_birth'].value_counts()
# Out:
# 2014-05-05T00:00:00    97
# 2014-04-21T00:00:00    95
# 2015-04-28T00:00:00    92
# 2015-09-01T00:00:00    91
# 2015-04-20T00:00:00    85
#                        ..
# 2004-12-07T00:00:00     1
# 2004-07-13T00:00:00     1
# 2009-07-16T00:00:00     1
# 2004-09-28T00:00:00     1
# 2007-12-17T00:00:00     1
# Name: date_of_birth, Length: 4883, dtype: int64

# %%
data['date_of_birth'] = data['date_of_birth'].str.extract(r'([0-9]{4}-[0-9]{2}-[0-9]{2})')
data['datetime'] = data['datetime'].str.extract(r'([0-9]{4}-[0-9]{2}-[0-9]{2})')
data['monthyear'] = data['monthyear'].str.extract(r'([0-9]{4}-[0-9]{2}-[0-9]{2})')

# %%
data
# Out:
#       age_upon_outcome animal_type                                breed  \
# 0              2 weeks         Cat               Domestic Shorthair Mix
# 1               1 year         Dog                           Beagle Mix
# 2               1 year         Dog                             Pit Bull
# 3              9 years         Dog              Miniature Schnauzer Mix
# 5             4 months         Dog                       Leonberger Mix
# ...                ...         ...                                  ...
# 78250          1 month         Dog  Golden Retriever/Labrador Retriever
# 78251          1 month         Dog  Golden Retriever/Labrador Retriever
# 78252          3 years         Dog                          Mastiff Mix
# 78254         2 months         Dog                   Standard Schnauzer
# 78255         2 months         Dog               Labrador Retriever Mix
#
#               color date_of_birth    datetime   monthyear     name  \
# 0      Orange Tabby    2014-07-07  2014-07-22  2014-07-22      NaN
# 1       White/Brown    2012-11-06  2013-11-07  2013-11-07     Lucy
# 2        Blue/White    2013-03-31  2014-06-03  2014-06-03  *Johnny
# 3             White    2005-06-02  2014-06-15  2014-06-15   Monday
# 5       Brown/White    2013-06-03  2013-10-07  2013-10-07   *Edgar
# ...             ...           ...         ...         ...      ...
# 78250   Brown/White    2017-12-04  2018-02-01  2018-02-01      NaN
# 78251   Brown/White    2017-12-04  2018-02-01  2018-02-01      NaN
# 78252    Blue/White    2014-12-30  2018-02-01  2018-02-01      Max
# 78254           Red    2017-11-13  2018-02-01  2018-02-01      NaN
# 78255   White/Brown    2017-11-13  2018-02-01  2018-02-01      NaN
#
#       outcome_subtype outcome_type sex_upon_outcome
# 0             Partner     Transfer      Intact Male
# 1             Partner     Transfer    Spayed Female
# 2                 NaN     Adoption    Neutered Male
# 3             Partner     Transfer    Neutered Male
# 5             Partner     Transfer      Intact Male
# ...               ...          ...              ...
# 78250          Foster     Adoption    Neutered Male
# 78251          Foster     Adoption    Spayed Female
# 78252             NaN     Adoption    Neutered Male
# 78254             NaN     Adoption    Spayed Female
# 78255             NaN     Adoption    Neutered Male
#
# [56609 rows x 11 columns]

# %%
# преобразуем в формат datetime

# %%
data['date_of_birth'] = pd.to_datetime(data['date_of_birth'])
data['datetime'] = pd.to_datetime(data['datetime'])
data['monthyear'] = pd.to_datetime(data['monthyear'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56609 entries, 0 to 78255
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age_upon_outcome  56609 non-null  object
#  1   animal_type       56609 non-null  object
#  2   breed             56609 non-null  object
#  3   color             56609 non-null  object
#  4   date_of_birth     56609 non-null  datetime64[ns]
#  5   datetime          56609 non-null  datetime64[ns]
#  6   monthyear         56609 non-null  datetime64[ns]
#  7   name              38660 non-null  object
#  8   outcome_subtype   29423 non-null  object
#  9   outcome_type      56609 non-null  object
#  10  sex_upon_outcome  56609 non-null  object
# dtypes: datetime64[ns](3), object(8)
# memory usage: 5.2+ MB

# %%
data['datetime'].equals(data['monthyear'])
# Out:
# True

# %%
# удалим столбец monthyear, так как он дублирует datetime
data = data.drop(['monthyear'], axis=1)

# %%
data
# Out:
#       age_upon_outcome animal_type                                breed  \
# 0              2 weeks         Cat               Domestic Shorthair Mix
# 1               1 year         Dog                           Beagle Mix
# 2               1 year         Dog                             Pit Bull
# 3              9 years         Dog              Miniature Schnauzer Mix
# 5             4 months         Dog                       Leonberger Mix
# ...                ...         ...                                  ...
# 78250          1 month         Dog  Golden Retriever/Labrador Retriever
# 78251          1 month         Dog  Golden Retriever/Labrador Retriever
# 78252          3 years         Dog                          Mastiff Mix
# 78254         2 months         Dog                   Standard Schnauzer
# 78255         2 months         Dog               Labrador Retriever Mix
#
#               color date_of_birth   datetime     name outcome_subtype  \
# 0      Orange Tabby    2014-07-07 2014-07-22      NaN         Partner
# 1       White/Brown    2012-11-06 2013-11-07     Lucy         Partner
# 2        Blue/White    2013-03-31 2014-06-03  *Johnny             NaN
# 3             White    2005-06-02 2014-06-15   Monday         Partner
# 5       Brown/White    2013-06-03 2013-10-07   *Edgar         Partner
# ...             ...           ...        ...      ...             ...
# 78250   Brown/White    2017-12-04 2018-02-01      NaN          Foster
# 78251   Brown/White    2017-12-04 2018-02-01      NaN          Foster
# 78252    Blue/White    2014-12-30 2018-02-01      Max             NaN
# 78254           Red    2017-11-13 2018-02-01      NaN             NaN
# 78255   White/Brown    2017-11-13 2018-02-01      NaN             NaN
#
#       outcome_type sex_upon_outcome
# 0         Transfer      Intact Male
# 1         Transfer    Spayed Female
# 2         Adoption    Neutered Male
# 3         Transfer    Neutered Male
# 5         Transfer      Intact Male
# ...            ...              ...
# 78250     Adoption    Neutered Male
# 78251     Adoption    Spayed Female
# 78252     Adoption    Neutered Male
# 78254     Adoption    Spayed Female
# 78255     Adoption    Neutered Male
#
# [56609 rows x 10 columns]

# %%
data['age'] = (data['datetime'] - data['date_of_birth'])

# %%
# data.loc[:, 'age'] = len(pd.date_range(data['date_of_birth'], data['datetime'], freq="D"))

# %%
data
# Out:
#       age_upon_outcome animal_type                                breed  \
# 0              2 weeks         Cat               Domestic Shorthair Mix
# 1               1 year         Dog                           Beagle Mix
# 2               1 year         Dog                             Pit Bull
# 3              9 years         Dog              Miniature Schnauzer Mix
# 5             4 months         Dog                       Leonberger Mix
# ...                ...         ...                                  ...
# 78250          1 month         Dog  Golden Retriever/Labrador Retriever
# 78251          1 month         Dog  Golden Retriever/Labrador Retriever
# 78252          3 years         Dog                          Mastiff Mix
# 78254         2 months         Dog                   Standard Schnauzer
# 78255         2 months         Dog               Labrador Retriever Mix
#
#               color date_of_birth   datetime     name outcome_subtype  \
# 0      Orange Tabby    2014-07-07 2014-07-22      NaN         Partner
# 1       White/Brown    2012-11-06 2013-11-07     Lucy         Partner
# 2        Blue/White    2013-03-31 2014-06-03  *Johnny             NaN
# 3             White    2005-06-02 2014-06-15   Monday         Partner
# 5       Brown/White    2013-06-03 2013-10-07   *Edgar         Partner
# ...             ...           ...        ...      ...             ...
# 78250   Brown/White    2017-12-04 2018-02-01      NaN          Foster
# 78251   Brown/White    2017-12-04 2018-02-01      NaN          Foster
# 78252    Blue/White    2014-12-30 2018-02-01      Max             NaN
# 78254           Red    2017-11-13 2018-02-01      NaN             NaN
# 78255   White/Brown    2017-11-13 2018-02-01      NaN             NaN
#
#       outcome_type sex_upon_outcome       age
# 0         Transfer      Intact Male   15 days
# 1         Transfer    Spayed Female  366 days
# 2         Adoption    Neutered Male  429 days
# 3         Transfer    Neutered Male 3300 days
# 5         Transfer      Intact Male  126 days
# ...            ...              ...       ...
# 78250     Adoption    Neutered Male   59 days
# 78251     Adoption    Spayed Female   59 days
# 78252     Adoption    Neutered Male 1129 days
# 78254     Adoption    Spayed Female   80 days
# 78255     Adoption    Neutered Male   80 days
#
# [56609 rows x 11 columns]

# %%
# age_upon_outcome, date_of_birth, datetime больше не нужны, удаляем
data = data.drop(['age_upon_outcome', 'date_of_birth', 'datetime'], axis=1)

# %%
data
# Out:
#       animal_type                                breed         color     name  \
# 0             Cat               Domestic Shorthair Mix  Orange Tabby      NaN
# 1             Dog                           Beagle Mix   White/Brown     Lucy
# 2             Dog                             Pit Bull    Blue/White  *Johnny
# 3             Dog              Miniature Schnauzer Mix         White   Monday
# 5             Dog                       Leonberger Mix   Brown/White   *Edgar
# ...           ...                                  ...           ...      ...
# 78250         Dog  Golden Retriever/Labrador Retriever   Brown/White      NaN
# 78251         Dog  Golden Retriever/Labrador Retriever   Brown/White      NaN
# 78252         Dog                          Mastiff Mix    Blue/White      Max
# 78254         Dog                   Standard Schnauzer           Red      NaN
# 78255         Dog               Labrador Retriever Mix   White/Brown      NaN
#
#       outcome_subtype outcome_type sex_upon_outcome       age
# 0             Partner     Transfer      Intact Male   15 days
# 1             Partner     Transfer    Spayed Female  366 days
# 2                 NaN     Adoption    Neutered Male  429 days
# 3             Partner     Transfer    Neutered Male 3300 days
# 5             Partner     Transfer      Intact Male  126 days
# ...               ...          ...              ...       ...
# 78250          Foster     Adoption    Neutered Male   59 days
# 78251          Foster     Adoption    Spayed Female   59 days
# 78252             NaN     Adoption    Neutered Male 1129 days
# 78254             NaN     Adoption    Spayed Female   80 days
# 78255             NaN     Adoption    Neutered Male   80 days
#
# [56609 rows x 8 columns]

# %%
data['sex_upon_outcome'].value_counts()
# Out:
# Neutered Male    20732
# Spayed Female    19949
# Intact Female     6873
# Intact Male       6294
# Unknown           2761
# Name: sex_upon_outcome, dtype: int64

# %%
data['sex'] = data['sex_upon_outcome'].str.extract(r' (\w+)')

# %%
data
# Out:
#       animal_type                                breed         color     name  \
# 0             Cat               Domestic Shorthair Mix  Orange Tabby      NaN
# 1             Dog                           Beagle Mix   White/Brown     Lucy
# 2             Dog                             Pit Bull    Blue/White  *Johnny
# 3             Dog              Miniature Schnauzer Mix         White   Monday
# 5             Dog                       Leonberger Mix   Brown/White   *Edgar
# ...           ...                                  ...           ...      ...
# 78250         Dog  Golden Retriever/Labrador Retriever   Brown/White      NaN
# 78251         Dog  Golden Retriever/Labrador Retriever   Brown/White      NaN
# 78252         Dog                          Mastiff Mix    Blue/White      Max
# 78254         Dog                   Standard Schnauzer           Red      NaN
# 78255         Dog               Labrador Retriever Mix   White/Brown      NaN
#
#       outcome_subtype outcome_type sex_upon_outcome       age     sex
# 0             Partner     Transfer      Intact Male   15 days    Male
# 1             Partner     Transfer    Spayed Female  366 days  Female
# 2                 NaN     Adoption    Neutered Male  429 days    Male
# 3             Partner     Transfer    Neutered Male 3300 days    Male
# 5             Partner     Transfer      Intact Male  126 days    Male
# ...               ...          ...              ...       ...     ...
# 78250          Foster     Adoption    Neutered Male   59 days    Male
# 78251          Foster     Adoption    Spayed Female   59 days  Female
# 78252             NaN     Adoption    Neutered Male 1129 days    Male
# 78254             NaN     Adoption    Spayed Female   80 days  Female
# 78255             NaN     Adoption    Neutered Male   80 days    Male
#
# [56609 rows x 9 columns]

# %%
data['sex'].value_counts()
# Out:
# Male      27026
# Female    26822
# Name: sex, dtype: int64

# %%
data['sex'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
data['Neuter'] = data['sex_upon_outcome'].str.extract(r'(\w+) ')

# %%
data
# Out:
#       animal_type                                breed         color     name  \
# 0             Cat               Domestic Shorthair Mix  Orange Tabby      NaN
# 1             Dog                           Beagle Mix   White/Brown     Lucy
# 2             Dog                             Pit Bull    Blue/White  *Johnny
# 3             Dog              Miniature Schnauzer Mix         White   Monday
# 5             Dog                       Leonberger Mix   Brown/White   *Edgar
# ...           ...                                  ...           ...      ...
# 78250         Dog  Golden Retriever/Labrador Retriever   Brown/White      NaN
# 78251         Dog  Golden Retriever/Labrador Retriever   Brown/White      NaN
# 78252         Dog                          Mastiff Mix    Blue/White      Max
# 78254         Dog                   Standard Schnauzer           Red      NaN
# 78255         Dog               Labrador Retriever Mix   White/Brown      NaN
#
#       outcome_subtype outcome_type sex_upon_outcome       age     sex  \
# 0             Partner     Transfer      Intact Male   15 days    Male
# 1             Partner     Transfer    Spayed Female  366 days  Female
# 2                 NaN     Adoption    Neutered Male  429 days    Male
# 3             Partner     Transfer    Neutered Male 3300 days    Male
# 5             Partner     Transfer      Intact Male  126 days    Male
# ...               ...          ...              ...       ...     ...
# 78250          Foster     Adoption    Neutered Male   59 days    Male
# 78251          Foster     Adoption    Spayed Female   59 days  Female
# 78252             NaN     Adoption    Neutered Male 1129 days    Male
# 78254             NaN     Adoption    Spayed Female   80 days  Female
# 78255             NaN     Adoption    Neutered Male   80 days    Male
#
#          Neuter
# 0        Intact
# 1        Spayed
# 2      Neutered
# 3      Neutered
# 5        Intact
# ...         ...
# 78250  Neutered
# 78251    Spayed
# 78252  Neutered
# 78254    Spayed
# 78255  Neutered
#
# [56609 rows x 10 columns]

# %%
data['Neuter'].value_counts()
# Out:
# Neutered    20732
# Spayed      19949
# Intact      13167
# Name: Neuter, dtype: int64

# %%
data['Neuter'].unique()
# Out:
# array(['Intact', 'Spayed', 'Neutered', nan], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56609 entries, 0 to 78255
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   animal_type       56609 non-null  object
#  1   breed             56609 non-null  object
#  2   color             56609 non-null  object
#  3   name              38660 non-null  object
#  4   outcome_subtype   29423 non-null  object
#  5   outcome_type      56609 non-null  object
#  6   sex_upon_outcome  56609 non-null  object
#  7   age               56609 non-null  timedelta64[ns]
#  8   sex               53848 non-null  object
#  9   Neuter            53848 non-null  object
# dtypes: object(9), timedelta64[ns](1)
# memory usage: 4.8+ MB

# %%
# столбец sex_upon_outcome можно удалить
data = data.drop(['sex_upon_outcome'], axis=1)

# %%
data
# Out:
#       animal_type                                breed         color     name  \
# 0             Cat               Domestic Shorthair Mix  Orange Tabby      NaN
# 1             Dog                           Beagle Mix   White/Brown     Lucy
# 2             Dog                             Pit Bull    Blue/White  *Johnny
# 3             Dog              Miniature Schnauzer Mix         White   Monday
# 5             Dog                       Leonberger Mix   Brown/White   *Edgar
# ...           ...                                  ...           ...      ...
# 78250         Dog  Golden Retriever/Labrador Retriever   Brown/White      NaN
# 78251         Dog  Golden Retriever/Labrador Retriever   Brown/White      NaN
# 78252         Dog                          Mastiff Mix    Blue/White      Max
# 78254         Dog                   Standard Schnauzer           Red      NaN
# 78255         Dog               Labrador Retriever Mix   White/Brown      NaN
#
#       outcome_subtype outcome_type       age     sex    Neuter
# 0             Partner     Transfer   15 days    Male    Intact
# 1             Partner     Transfer  366 days  Female    Spayed
# 2                 NaN     Adoption  429 days    Male  Neutered
# 3             Partner     Transfer 3300 days    Male  Neutered
# 5             Partner     Transfer  126 days    Male    Intact
# ...               ...          ...       ...     ...       ...
# 78250          Foster     Adoption   59 days    Male  Neutered
# 78251          Foster     Adoption   59 days  Female    Spayed
# 78252             NaN     Adoption 1129 days    Male  Neutered
# 78254             NaN     Adoption   80 days  Female    Spayed
# 78255             NaN     Adoption   80 days    Male  Neutered
#
# [56609 rows x 9 columns]

# %%
data['outcome_subtype'].unique()
# Out:
# array(['Partner', nan, 'Offsite', 'Foster', 'SCRP', 'Barn', 'Snr'],
#       dtype=object)

# %%
data['outcome_subtype'].value_counts()
# Out:
# Partner    19658
# Foster      5558
# SCRP        3211
# Snr          626
# Offsite      367
# Barn           3
# Name: outcome_subtype, dtype: int64

# %%
data['name'].value_counts()
# Out:
# Bella          204
# Max            169
# Luna           158
# Daisy          146
# Lucy           135
#               ...
# Leu              1
# *Bullwinkle      1
# Buppie           1
# Nunki            1
# Doty             1
# Name: name, Length: 11989, dtype: int64

# %%
data['name'].unique()
# Out:
# array([nan, 'Lucy', '*Johnny', ..., 'Wonder Woman', 'Eisley',
#        'Allee Chat'], dtype=object)

# %%
data['name'].nunique()
# Out:
# 11989

# %%
# столбец name можно удалить
data = data.drop(['name'], axis=1)

# %%
data
# Out:
#       animal_type                                breed         color  \
# 0             Cat               Domestic Shorthair Mix  Orange Tabby
# 1             Dog                           Beagle Mix   White/Brown
# 2             Dog                             Pit Bull    Blue/White
# 3             Dog              Miniature Schnauzer Mix         White
# 5             Dog                       Leonberger Mix   Brown/White
# ...           ...                                  ...           ...
# 78250         Dog  Golden Retriever/Labrador Retriever   Brown/White
# 78251         Dog  Golden Retriever/Labrador Retriever   Brown/White
# 78252         Dog                          Mastiff Mix    Blue/White
# 78254         Dog                   Standard Schnauzer           Red
# 78255         Dog               Labrador Retriever Mix   White/Brown
#
#       outcome_subtype outcome_type       age     sex    Neuter
# 0             Partner     Transfer   15 days    Male    Intact
# 1             Partner     Transfer  366 days  Female    Spayed
# 2                 NaN     Adoption  429 days    Male  Neutered
# 3             Partner     Transfer 3300 days    Male  Neutered
# 5             Partner     Transfer  126 days    Male    Intact
# ...               ...          ...       ...     ...       ...
# 78250          Foster     Adoption   59 days    Male  Neutered
# 78251          Foster     Adoption   59 days  Female    Spayed
# 78252             NaN     Adoption 1129 days    Male  Neutered
# 78254             NaN     Adoption   80 days  Female    Spayed
# 78255             NaN     Adoption   80 days    Male  Neutered
#
# [56609 rows x 8 columns]

# %%
# data.describe(include='object')

# %%
data.sex_upon_outcome.value_counts()
# Out:
# Neutered Male    20732
# Spayed Female    19949
# Intact Female     6873
# Intact Male       6294
# Unknown           2761
# Name: sex_upon_outcome, dtype: int64

# %%
# data.hist(figsize=(15,15))
# plt.show()

# %%
# data.boxplot(figsize=(15,6), rot=90)

# %%
# sns.heatmap(data.corr(),annot=True,cmap='RdBu',linewidths=0.2) #data.corr()-->матрица корреляций
# # gcf() - получение текущей фигуры
# fig=plt.gcf()
# # set_size_inches() - установить размер фигуры
# fig.set_size_inches(12,12)
# plt.show()

# %%
# !pip install pandas_profiling

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-472-7e92257ce716> in <module>
# ----> 1 pandas_profiling.ProfileReport(data)
#
# ~\anaconda3\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# ~\anaconda3\lib\site-packages\pandas_profiling\describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# --> 392     variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
#     393     variable_stats.columns.names = df.columns.names
#     394
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'

# %%
data.profile_report()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-0a63388c6925> in <module>
# ----> 1 data.profile_report()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'
